# %%
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu

# %%
references = [['I', 'love', 'eating', 'ice', 'cream'], ['He', 'enjoys', 'eating', 'cake']]
translations = [['I', 'love', 'eating', 'ice', 'cream'], ['He', 'likes', 'to', 'eat', 'cake']]
 
# Create a list of reference lists
references_list = [[ref] for ref in references]
 
# Calculate BLEU score for the entire corpus
bleu_score_corpus = corpus_bleu(references_list, translations)
print("Corpus BLEU Score: ", bleu_score_corpus)
# Out:
# Corpus BLEU Score:  0.5438786529686386

# %%
print(sentence_bleu([["This", "is", "an", "apple"]], ["This", "is", "an", "apple"]))
# Out:
# 1.0

# %%
import nltk

# %%
nltk.download("all")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_rus.zip.
# [nltk_data]    | Downloading package basque_grammars to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package crubadan to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package floresta to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package kimmo to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package large_grammars to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/maxent_treebank_pos_tagger_tab.zip.
# [nltk_data]    | Downloading package moses_sample to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package paradigms to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package punkt_tab to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data]    | Downloading package qc to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package rslp to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package senseval to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package tagsets_json to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets_json.zip.
# [nltk_data]    | Downloading package timit to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /Users/utsubo-katsuhiko/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package verbnet to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /Users/utsubo-
# [nltk_data]    |     katsuhiko/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
from nltk.tokenize import sent_tokenize, word_tokenize 
  
text = "Natural language processing (NLP) is a field of computer science, artificial intelligence and computational linguistics concerned with the interactions between computers and human (natural) languages, and, in particular, concerned with programming computers to fruitfully process large natural language corpora. Challenges in natural language processing frequently involve natural language understanding, natural language generation (frequently from formal, machine-readable logical forms), connecting language and machine perception, managing human-computer dialog systems, or some combination thereof."
  
print(sent_tokenize(text)) 
print(word_tokenize(text))
# Out:
# ['Natural language processing (NLP) is a field of computer science, artificial intelligence and computational linguistics concerned with the interactions between computers and human (natural) languages, and, in particular, concerned with programming computers to fruitfully process large natural language corpora.', 'Challenges in natural language processing frequently involve natural language understanding, natural language generation (frequently from formal, machine-readable logical forms), connecting language and machine perception, managing human-computer dialog systems, or some combination thereof.']
# ['Natural', 'language', 'processing', '(', 'NLP', ')', 'is', 'a', 'field', 'of', 'computer', 'science', ',', 'artificial', 'intelligence', 'and', 'computational', 'linguistics', 'concerned', 'with', 'the', 'interactions', 'between', 'computers', 'and', 'human', '(', 'natural', ')', 'languages', ',', 'and', ',', 'in', 'particular', ',', 'concerned', 'with', 'programming', 'computers', 'to', 'fruitfully', 'process', 'large', 'natural', 'language', 'corpora', '.', 'Challenges', 'in', 'natural', 'language', 'processing', 'frequently', 'involve', 'natural', 'language', 'understanding', ',', 'natural', 'language', 'generation', '(', 'frequently', 'from', 'formal', ',', 'machine-readable', 'logical', 'forms', ')', ',', 'connecting', 'language', 'and', 'machine', 'perception', ',', 'managing', 'human-computer', 'dialog', 'systems', ',', 'or', 'some', 'combination', 'thereof', '.']

# %%
import pandas as pd

df=pd.read_csv("outfile.txt",sep="\t")
df
# Out:
#           no   search                                                src  \
# 0          0  greeedy              Une nouvelle difficulté est apparue .
# 1          1  greeedy                    Ça ne va pas bien se terminer .
# 2          2  greeedy                        Je ne le dirai à personne .
# 3          3  greeedy  Vous n'êtes pas autorisé à amener des chiens d...
# 4          4  greeedy                                    Tu peux nager .
# ...      ...      ...                                                ...
# 13579  13579  greeedy  Je pensais que vous seriez rassasiés après avo...
# 13580  13580  greeedy                        Ma mère prépare mes repas .
# 13581  13581  greeedy       Aide-moi avec mon devoir , s ’ il te plaît .
# 13582  13582  greeedy                      Je ne comprends pas même ça .
# 13583  13583  greeedy                 L'une des pommes tomba par terre .
#
#                                                      tgt  \
# 0                          A new difficulty has arisen .
# 1                          It 's not going to end well .
# 2                                I wo n't tell anybody .
# 3      You are not permitted to bring dogs into this ...
# 4                                         You may swim .
# ...                                                  ...
# 13579  I thought you 'd be full after eating that big...
# 13580                      My mother prepares my meals .
# 13581                Help me with my homework , please .
# 13582                    I do n't even understand that .
# 13583             One of the apples fell to the ground .
#
#                                                     pred      prob
# 0                           A new system has come out .  -5.657370
# 1                               It wo n't happen soon .  -3.098270
# 2                                I wo n't tell anyone .  -0.459455
# 3       You are not permitted to bring dogs into this... -3.167453
# 4                                        You can swim .  -0.090315
# ...                                                  ...       ...
# 13579   I thought you 'd be eating that steak before ... -6.760383
# 13580                   My mother is making my dinner .  -2.774312
# 13581                Please help me come with my help .  -3.613328
# 13582                   I do n't even understand that .  -1.736605
# 13583                  One of the apples were painted .  -4.560697
#
# [13584 rows x 6 columns]

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
