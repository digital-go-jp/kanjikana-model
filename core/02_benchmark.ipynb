# %% [markdown]
# 各モデルで実施してきた、家族口座データによるベンチマーク 18万件  /AnalysisData/input.txt

# %%
import os
ver='1.6.1o'
os.environ['ver']=ver

# %%
# !mkdir -p data/data.$ver
# !rm -rf data/data.$ver/*jar
# !cp -p lib/kanjikana_core-*jar data/data.$ver
# !cp -p run.sh data/data.$ver
# !cp -pr conf data/data.$ver/.


# !cp /AnalysisData/input.txt data/data.$ver/input.txt

# %%
# !mkdir -p .djl.ai

# %%
# ENSEMBLE
# !docker stop $(docker ps -a -q)
#!docker rm $(docker ps -a -q)
# !docker rm -f `docker ps -a -q`
# !docker rmi `docker images -q`

# %%
# !docker build -t kanjikana.$ver .

# %%
# !docker run -itd -v $PWD/data/data.$ver:/mnt kanjikana.$ver /bin/bash

# %%
# !docker stop $(docker ps -a -q)
# !docker rm $(docker ps -a -q)

# !docker build -t kanjikana .
# !docker run -itd -v $PWD/data/data.$ver:/mnt kanjikana /bin/bash
# !docker exec -it $(docker ps -a -q) bash /mnt/run.sh > /dev/null

# %%
#SIMPLE
# !cat run.sh |sed "s/ENSEMBLE/BASIC/g"|sed 's/output.txt/output_simple.txt/g' > data/data.$ver/run_simple.sh

# %%
# !docker stop $(docker ps -a -q)
# !docker rm $(docker ps -a -q)

# !docker build -t kanjikana .
# !docker run -itd -v $PWD/data/data.$ver:/mnt kanjikana /bin/bash
# !docker exec -it $(docker ps -a -q) bash /mnt/run_simple.sh > /dev/null

# %%
# only_dict
# !cat run.sh |sed "s/ENSEMBLE/ONLY_DICT/g"|sed 's/output.txt/output_only_dict.txt/g' > data/data.$ver/run_only_dict.sh

# %%
# !docker stop $(docker ps -a -q)
# !docker rm $(docker ps -a -q)

# !docker build -t kanjikana .
# !docker run -itd -v $PWD/data/data.$ver:/mnt kanjikana /bin/bash
# !docker exec -it $(docker ps -a -q) bash /mnt/run_only_dict.sh > log.txt

# %%
# only_stat
# !cat run.sh |sed "s/ENSEMBLE/ONLY_STAT/g"|sed 's/output.txt/output_only_stat.txt/g' > data/data.$ver/run_only_stat.sh

# %%
# !docker stop $(docker ps -a -q)
# !docker rm $(docker ps -a -q)

# !docker build -t kanjikana .
# !docker run -itd -v $PWD/data/data.$ver:/mnt kanjikana /bin/bash
# !docker exec -it $(docker ps -a -q) bash /mnt/run_only_stat.sh > /dev/null

# %%
# only_ai
# !cat run.sh |sed "s/ENSEMBLE/ONLY_AI/g"|sed 's/output.txt/output_only_ai.txt/g' > data/data.$ver/run_only_ai.sh

# %%
# !docker stop $(docker ps -a -q)
# !docker rm $(docker ps -a -q)

# !docker build -t kanjikana .
# !docker run -itd -v $PWD/data/data.$ver:/mnt kanjikana /bin/bash
# !docker exec -it $(docker ps -a -q) bash /mnt/run_only_ai.sh > /dev/null

# %%
#NANDOKU_BASICS
# !cat run.sh |sed "s/ENSEMBLE/NANDOKU_BASIC/g"|sed 's/output.txt/output_nandoku_simple.txt/g' > data/data.$ver/run_nandoku_simple.sh

# %%
# !docker stop $(docker ps -a -q)
# !docker rm $(docker ps -a -q)

# !docker build -t kanjikana .
# !docker run -itd -v $PWD/data/data.$ver:/mnt kanjikana /bin/bash
# !docker exec -it $(docker ps -a -q) bash /mnt/run_nandoku_simple.sh > /dev/null

# %%
#NANDOKU_ENSEMBLE
# !cat run.sh |sed "s/ENSEMBLE/NANDOKU_ENSEMBLE/g"|sed 's/output.txt/output_nandoku.txt/g' > data/data.$ver/run_nandoku.sh

# %%
# !docker stop $(docker ps -a -q)
# !docker rm $(docker ps -a -q)

# !docker build -t kanjikana .
# !docker run -itd -v $PWD/data/data.$ver:/mnt kanjikana /bin/bash
# !docker exec -it $(docker ps -a -q) bash /mnt/run_nandoku.sh > /dev/null

# %%
# !date
