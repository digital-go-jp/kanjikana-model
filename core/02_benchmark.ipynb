# %% [markdown]
# 各モデルで実施してきた、家族口座データによるベンチマーク 18万件  /AnalysisData/input.txt

# %%
import os
ver='1.7o'
os.environ['ver']=ver

# %%
# !mkdir -p data/data.$ver
# !rm -rf data/data.$ver/*jar
# !cp -p lib/kanjikana_core-*$ver*jar data/data.$ver
# !cp -p run.sh data/data.$ver
# !cp -pr conf data/data.$ver/.


# !cp /AnalysisData/input.txt data/data.$ver/input.txt

# %%
# !mkdir -p .djl.ai

# %%
# !docker stop  $(docker ps -a -q)
# !docker rm -f $(docker ps -a -q)
# !docker rmi -f $(docker images -q)

# !docker build -t kanjikana .
# !docker run -itd -v $PWD/data/data.$ver:/mnt kanjikana /bin/bash
# !docker exec -it $(docker ps -a -q) bash /mnt/run.sh
# Out:
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# WARN[0010] StopSignal SIGTERM failed to stop container elegant_ramanujan in 10 seconds, resorting to SIGKILL
# f9ee222661d5
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# f9ee222661d5
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Untagged: localhost/kanjikana:latest
# Untagged: public.ecr.aws/amazonlinux/amazonlinux:2023
# Deleted: 18627a9a970948af7aaca3200eb7e3fa3b1a00a9fdb02e430be8916369f136b8
# Deleted: abad61b71cb3e5b2e6226c0d10540c13bca37890209e270f275979a623cf892c
# Deleted: d0501e8d5ef3aba64ee8aacbf3fe45285c5ab387a6e902af94c45c9129412403
# ...

# %%
#SIMPLE
# !cat run.sh |sed "s/ENSEMBLE/BASIC/g"|sed 's/output.txt/output_simple.txt/g' > data/data.$ver/run_simple.sh

# %%
# !docker stop  $(docker ps -a -q)
# !docker rm -f $(docker ps -a -q)
# !docker rmi -f $(docker images -q)

# !docker build -t kanjikana .
# !docker run -itd -v $PWD/data/data.$ver:/mnt kanjikana /bin/bash
# !docker exec -it $(docker ps -a -q) bash /mnt/run_simple.sh
# Out:
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# WARN[0010] StopSignal SIGTERM failed to stop container blissful_bardeen in 10 seconds, resorting to SIGKILL
# 9658d22e40c6
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# 9658d22e40c6
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Untagged: localhost/kanjikana:latest
# Untagged: public.ecr.aws/amazonlinux/amazonlinux:2023
# Deleted: 3e9c483835ce2d5887b327c14f95e66ad26b2108c41afbb4d23f29622b6e4e4d
# Deleted: 8c73c1b9deb30b74a3d4085ca9b62b831eca2f4e51e267b0180c6a2548f4c38b
# Deleted: f5ef7d91f4bf9532fc77d9682d0202ceccb0a4d5aebf57e1fb0ed71509285da5
# ...

# %%
# only_dict
# !cat run.sh |sed "s/ENSEMBLE/ONLY_DICT/g"|sed 's/output.txt/output_only_dict.txt/g' > data/data.$ver/run_only_dict.sh

# %%
# !docker stop  $(docker ps -a -q)
# !docker rm -f $(docker ps -a -q)
# !docker rmi -f $(docker images -q)

# !docker build -t kanjikana .
# !docker run -itd -v $PWD/data/data.$ver:/mnt kanjikana /bin/bash
# !docker exec -it $(docker ps -a -q) bash /mnt/run_only_dict.sh
# Out:
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# WARN[0010] StopSignal SIGTERM failed to stop container elated_sutherland in 10 seconds, resorting to SIGKILL
# 2d355eb93d53
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# 2d355eb93d53
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Untagged: localhost/kanjikana:latest
# Untagged: public.ecr.aws/amazonlinux/amazonlinux:2023
# Deleted: a2b3a8abc82bfa403d6f326ce810987bb947c81b689992f654231acfed62fa42
# Deleted: 581a25d01460b923983e5b3284e02a454ebfc142dd5d3e776bd81ca508512188
# Deleted: bc6f820a139a569ee23ae97a8b4228ea9092d6b4e8490bb28306a3f4791a4e88
# ...

# %%
# only_stat
# !cat run.sh |sed "s/ENSEMBLE/ONLY_STAT/g"|sed 's/output.txt/output_only_stat.txt/g' > data/data.$ver/run_only_stat.sh

# %%
# !docker stop  $(docker ps -a -q)
# !docker rm -f $(docker ps -a -q)
# !docker rmi -f $(docker images -q)

# !docker build -t kanjikana .
# !docker run -itd -v $PWD/data/data.$ver:/mnt kanjikana /bin/bash
# !docker exec -it $(docker ps -a -q) bash /mnt/run_only_stat.sh
# Out:
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# WARN[0010] StopSignal SIGTERM failed to stop container priceless_darwin in 10 seconds, resorting to SIGKILL
# b72ffc84f1bf
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# b72ffc84f1bf
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Untagged: localhost/kanjikana:latest
# Untagged: public.ecr.aws/amazonlinux/amazonlinux:2023
# Deleted: 2954deea5d4e1e24ac10f00333bd1a971c3a1c4690599b13b483810420e3da23
# Deleted: ad4b3aa7a5b02cf5e4c98d377dd75e1039aa39e5e62888ca57db08e26a3a587c
# Deleted: 6cc365493baed8706ab04f2cc22c120d229d5865e95f416e89860f4115b55852
# ...

# %%
# only_ai
# !cat run.sh |sed "s/ENSEMBLE/ONLY_AI/g"|sed 's/output.txt/output_only_ai.txt/g' > data/data.$ver/run_only_ai.sh

# %%
# !docker stop  $(docker ps -a -q)
# !docker rm -f $(docker ps -a -q)
# !docker rmi -f $(docker images -q)

# !docker build -t kanjikana .
# !docker run -itd -v $PWD/data/data.$ver:/mnt kanjikana /bin/bash
# !docker exec -it $(docker ps -a -q) bash /mnt/run_only_ai.sh
# Out:
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# WARN[0010] StopSignal SIGTERM failed to stop container confident_noyce in 10 seconds, resorting to SIGKILL
# 3e08d0b9b35f
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# 3e08d0b9b35f
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Untagged: localhost/kanjikana:latest
# Untagged: public.ecr.aws/amazonlinux/amazonlinux:2023
# Deleted: d59540523212297c5930cadd703eab96b20cb059e82b92980142e3c7eb3cb9ac
# Deleted: 54a9aa3f9a5b06c8cfeec9383b6e5c79804dcdb4905360edf0e3a5b1d09a82bd
# Deleted: 9cea187d16059096a0b111b91f4902e3ec614f8c33630e550de871858f3ee77c
# ...

# %%
# !date
# Out:
# 2025年  6月 20日 金曜日 03:31:44 JST
