# %% [markdown]
# # 辞書とAIモデルをコピーし、jarファイルを作成する

# %%
import os
os.environ["VER"]="1.7o"
version=os.environ['VER']

# %%
# !rm -rf target

# %%
print(version)
# Out:
# 1.7o

# %%
# !rm -rf src/main/resources/ai/*

# %%
# !rm -rf src/main/resources/ai_r/*

# %%
# !rm -rf src/main/resources/dict/*

# %%
import glob
import shutil
for fname in glob.glob(f'../train/model/model.{version}/*.pt'):
    if "checkpoint" in fname:
        continue

    shutil.copy(fname,'src/main/resources/ai/')

# %%
for fname in glob.glob(f'../train/model/model.{version}/*.txt'):
    if fname.startswith("checkpoint"):
        continue

    shutil.copy(fname,'src/main/resources/ai/')

# %%
for fname in glob.glob(f'../train/model/model.{version}/*.json'):
    if fname.startswith("checkpoint"):
        continue

    shutil.copy(fname,'src/main/resources/ai/')

# %%
for fname in glob.glob(f'../train/model/model_r.{version}/*.pt'):
    if "checkpoint" in fname:
        continue

    shutil.copy(fname,'src/main/resources/ai_r/')

# %%
for fname in glob.glob(f'../train/model/model_r.{version}/*.txt'):
    if fname.startswith("checkpoint"):
        continue

    shutil.copy(fname,'src/main/resources/ai_r/')

# %%
for fname in glob.glob(f'../train/model/model_r.{version}/*.json'):
    if fname.startswith("checkpoint"):
        continue

    shutil.copy(fname,'src/main/resources/ai_r/')

# %%
for fname in glob.glob(f'../dict/data/data.{version}/*json'):
    shutil.copy(fname,'src/main/resources/dict/')

# %%
with open("kanjikana.properties",'r',encoding='utf-8') as f:
    lst = [l.rstrip() for l in f]


newlst=[]
for l in lst:
    newlst.append(l.replace(r"${project.version}",version))

with open("src/main/resources/kanjikana.properties",'w',encoding='utf-8') as f:
    for l in newlst:
        f.write(l+"\n")

# %%
# !cat pom.xml.template |sed s/VER/$VER/ > pom.xml 
# !mvn clean compile assembly:single

# !mkdir -p lib
# !mv target/*jar lib
# Out:
# [INFO] Scanning for projects...
# [INFO]
# [INFO] ---------------< jp.go.digital.kanjikana:kanjikana_core >---------------
# [INFO] Building kanjikana_core 1.7o
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:2.5:clean (default-clean) @ kanjikana_core ---
# [INFO]
# [INFO] --- maven-resources-plugin:3.2.0:resources (default-resources) @ kanjikana_core ---
# [INFO] Using 'UTF-8' encoding to copy filtered resources.
# [INFO] Using 'UTF-8' encoding to copy filtered properties files.
# [INFO] Copying 27 resources
# [INFO] The encoding used to copy filtered properties files have not been set. This means that the same encoding will be used to copy filtered properties files as when copying other filtered resources. This might not be what you want! Run your build with --debug to see which files might be affected. Read more at https://maven.apache.org/plugins/maven-resources-plugin/examples/filtering-properties-files.html
# [INFO]
# [INFO] --- maven-compiler-plugin:3.1:compile (default-compile) @ kanjikana_core ---
# [INFO] Changes detected - recompiling the module!
# [INFO] Compiling 129 source files to /home/analysis01/src/kanjikana-model/core/target/classes
# [WARNING] /home/analysis01/src/kanjikana-model/core/src/main/java/jp/go/digital/kanjikana/core/executor/match/KanjiKanaMatchRunner.java: 一部の入力ファイルは推奨されないAPIを使用またはオーバーライドしています。
# [WARNING] /home/analysis01/src/kanjikana-model/core/src/main/java/jp/go/digital/kanjikana/core/executor/match/KanjiKanaMatchRunner.java: 詳細は、-Xlint:deprecationオプションを指定して再コンパイルしてください。
# [WARNING] /home/analysis01/src/kanjikana-model/core/src/main/java/jp/go/digital/kanjikana/core/engine/dict/impl/DictAsIsNormalized.java: 入力ファイルの操作のうち、未チェックまたは安全ではないものがあります。
# [WARNING] /home/analysis01/src/kanjikana-model/core/src/main/java/jp/go/digital/kanjikana/core/engine/dict/impl/DictAsIsNormalized.java: 詳細は、-Xlint:uncheckedオプションを指定して再コンパイルしてください。
# [INFO]
# [INFO] --- maven-assembly-plugin:3.5.0:single (default-cli) @ kanjikana_core ---
# [INFO] Building jar: /home/analysis01/src/kanjikana-model/core/target/kanjikana_core-1.7o-jar-with-dependencies.jar
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time: 47.532 s
# [INFO] Finished at: 2025-06-18T15:38:24+09:00
# [INFO] ------------------------------------------------------------------------
