# %% [markdown]
# OSSとCRALWデータ、及び単漢字から訓練する

# %%
import os
with open('../version.txt','r',encoding='utf-8') as f:
    for l in f:
        ver=l.rstrip()
        break
os.environ["VER"]=ver
os.environ['DATA']='../dict/data/data.'+os.environ["VER"]
os.environ['DIR']='dataset/dataset.'+os.environ["VER"]
os.environ['LOG']='logs/logs_r.'+os.environ["VER"]
os.environ['MODEL']='model/model_r.'+os.environ["VER"]

# %%
# !echo $VER
# Out:
# 1.8o

# %%
#training

# %%
# !python ./transformer_model.py \
  --emb_size 512 \
  --nhead 8 \
  --ffn_hid_dim 2048 \
  --batch_size 64 \
  --num_encoder_layers 8 \
  --num_decoder_layers 8 \
  --lr 0.00002 \
  --dropout 0.3 \
  --num_epochs 100 \
  --device cuda \
  --earlystop_patient 3 \
  --output_dir $MODEL \
  --tensorboard_logdir $LOG \
  --source_lang kana \
  --target_lang kanji \
  --train_file $DIR/train.jsonl \
  --valid_file $DIR/valid.jsonl
# Out:
# [00:00:08] Pre-processing sequences       ██████████████████ 0        /        0[00:00:00] Pre-processing sequences       ██████████████████ 0        /        0/home/analysis01/src/kanjikana-private/venv/lib/python3.11/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# num_epochs:100
# /home/analysis01/src/kanjikana-private/venv/lib/python3.11/site-packages/torch/nn/functional.py:6041: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# Epoch: 1, Train loss: 3.978, Val loss: 2.840, Epoch time = 7614.809s
# Epoch: 2, Train loss: 2.693, Val loss: 1.919, Epoch time = 7624.560s
# Epoch: 3, Train loss: 1.893, Val loss: 1.224, Epoch time = 7597.727s
# Epoch: 4, Train loss: 1.407, Val loss: 1.006, Epoch time = 7565.609s
# Epoch: 5, Train loss: 1.200, Val loss: 0.910, Epoch time = 7556.162s
# Epoch: 6, Train loss: 1.085, Val loss: 0.839, Epoch time = 7617.191s
# Epoch: 7, Train loss: 1.013, Val loss: 0.789, Epoch time = 7569.145s
# Epoch: 8, Train loss: 0.962, Val loss: 0.757, Epoch time = 7614.052s
# Epoch: 9, Train loss: 0.925, Val loss: 0.736, Epoch time = 7652.498s
# Epoch: 10, Train loss: 0.895, Val loss: 0.713, Epoch time = 7641.896s
# Epoch: 11, Train loss: 0.871, Val loss: 0.697, Epoch time = 7551.419s
# Epoch: 12, Train loss: 0.852, Val loss: 0.684, Epoch time = 7555.573s
# Epoch: 13, Train loss: 0.835, Val loss: 0.672, Epoch time = 7586.775s
# Epoch: 14, Train loss: 0.820, Val loss: 0.661, Epoch time = 7562.045s
# Epoch: 15, Train loss: 0.807, Val loss: 0.652, Epoch time = 7663.096s
# Epoch: 16, Train loss: 0.796, Val loss: 0.646, Epoch time = 7582.492s
# Epoch: 17, Train loss: 0.786, Val loss: 0.641, Epoch time = 7547.535s
# Epoch: 18, Train loss: 0.777, Val loss: 0.636, Epoch time = 7552.093s
# Epoch: 19, Train loss: 0.769, Val loss: 0.635, Epoch time = 7636.946s
# Epoch: 20, Train loss: 0.763, Val loss: 0.626, Epoch time = 7553.783s
# Epoch: 21, Train loss: 0.757, Val loss: 0.628, Epoch time = 7553.413s
# Epoch: 22, Train loss: 0.757, Val loss: 0.629, Epoch time = 7651.408s
# Epoch: 23, Train loss: 0.756, Val loss: 0.611, Epoch time = 7607.384s
# Epoch: 24, Train loss: 0.746, Val loss: 0.608, Epoch time = 7665.512s
# Epoch: 25, Train loss: 0.738, Val loss: 0.603, Epoch time = 7576.306s
# Epoch: 26, Train loss: 0.734, Val loss: 0.604, Epoch time = 7609.013s
# Epoch: 27, Train loss: 0.729, Val loss: 0.602, Epoch time = 7559.742s
# Epoch: 28, Train loss: 0.725, Val loss: 0.599, Epoch time = 7556.331s
# Epoch: 29, Train loss: 0.721, Val loss: 0.597, Epoch time = 7554.002s
# Epoch: 30, Train loss: 0.718, Val loss: 0.594, Epoch time = 7551.390s
# Epoch: 31, Train loss: 0.715, Val loss: 0.593, Epoch time = 7539.984s
# Epoch: 32, Train loss: 0.711, Val loss: 0.591, Epoch time = 7554.761s
# Epoch: 33, Train loss: 0.708, Val loss: 0.590, Epoch time = 7550.542s
# Epoch: 34, Train loss: 0.705, Val loss: 0.590, Epoch time = 7554.016s
# Epoch: 35, Train loss: 0.703, Val loss: 0.589, Epoch time = 7555.745s
# Epoch: 36, Train loss: 0.700, Val loss: 0.585, Epoch time = 7562.697s
# Epoch: 37, Train loss: 0.697, Val loss: 0.585, Epoch time = 7607.815s
# Epoch: 38, Train loss: 0.695, Val loss: 0.585, Epoch time = 7559.898s
# Epoch: 39, Train loss: 0.692, Val loss: 0.585, Epoch time = 7662.239s
# Epoch: 40, Train loss: 0.690, Val loss: 0.584, Epoch time = 7554.286s
# Epoch: 41, Train loss: 0.688, Val loss: 0.583, Epoch time = 7642.136s
# Epoch: 42, Train loss: 0.686, Val loss: 0.582, Epoch time = 7629.500s
# Epoch: 43, Train loss: 0.684, Val loss: 0.581, Epoch time = 7552.701s
# Epoch: 44, Train loss: 0.683, Val loss: 0.580, Epoch time = 7553.455s
# Epoch: 45, Train loss: 0.681, Val loss: 0.582, Epoch time = 7552.323s
# Epoch: 46, Train loss: 0.679, Val loss: 0.579, Epoch time = 7589.767s
# Epoch: 47, Train loss: 0.678, Val loss: 0.582, Epoch time = 7553.343s
# Epoch: 48, Train loss: 0.676, Val loss: 0.583, Epoch time = 7551.564s
# Epoch: 49, Train loss: 0.674, Val loss: 0.580, Epoch time = 7553.940s
# Epoch: 50, Train loss: 0.673, Val loss: 0.582, Epoch time = 7554.374s

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir logs/logs_r.$VER
# Out:
#       <iframe id="tensorboard-frame-d2200347f7cfa703" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d2200347f7cfa703");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !python ./generate.py \
    --test_file $DIR/test.jsonl \
    --model_file $MODEL/checkpoint_best.pt \
    --outfile $DIR/generate.txt \
    --source_lang kana \
    --target_lang kanji \
    --device cpu \
    --nbest 5 \
    --beam_width 5 \
    --max_len 100 \
    --search beam
# Out:
# /home/analysis01/src/kanjikana-private/venv/lib/python3.11/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(

# %%
# !python evaluate.py --infile $DIR/generate_r.txt
# Out:
# Traceback (most recent call last):
#   File "/home/analysis01/src/kanjikana-private/train/evaluate.py", line 60, in <module>
#     main()
#   File "/home/analysis01/src/kanjikana-private/train/evaluate.py", line 56, in main
#     run(args)
#   File "/home/analysis01/src/kanjikana-private/train/evaluate.py", line 15, in run
#     with open(args.infile,'r',encoding='utf-8') as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/dataset.1.8o/generate_r.txt'

# %%
# !date
# Out:
# 2025年  9月 13日 土曜日 21:12:29 JST
