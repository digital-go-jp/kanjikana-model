# %%
import os
with open('../version.txt','r',encoding='utf-8') as f:
    for l in f:
        ver=l.rstrip()
        break
os.environ["VER"]=ver
os.environ['DATA']='../dict/data/data.'+os.environ["VER"]
os.environ['DIR']='dataset/dataset.'+os.environ["VER"]
os.environ['LOG']='logs/logs.'+os.environ["VER"]
os.environ['MODEL']='model/model.'+os.environ["VER"]

# %%
# !python conv_scripted.py  \
    --model_file=$MODEL/checkpoint_best.pt \
    --model_script=$MODEL/script_$VER.pt \
    --encoder=$MODEL/encoder_$VER.pt \
    --decoder=$MODEL/decoder_$VER.pt \
    --positional_encoding=$MODEL/positional_encoding_$VER.pt \
    --generator=$MODEL/generator_$VER.pt \
    --src_tok_emb=$MODEL/src_tok_emb_$VER.pt \
    --tgt_tok_emb=$MODEL/tgt_tok_emb_$VER.pt \
    --vocab_src=$MODEL/vocab_src_$VER.txt \
    --vocab_tgt=$MODEL/vocab_tgt_$VER.txt \
    --params=$MODEL/params_$VER.json \
    --device=cpu
# Out:
# /Users/utsubo-katsuhiko/src/kanjikana-private/venv/lib/python3.13/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# /Users/utsubo-katsuhiko/src/kanjikana-private/venv/lib/python3.13/site-packages/torch/jit/_recursive.py:313: UserWarning: 'norm' was found in ScriptModule constants,  but it is a non-constant submodule. Consider removing it.
#   warnings.warn(
# Traceback (most recent call last):
#   File "/Users/utsubo-katsuhiko/src/kanjikana-private/train/conv_scripted.py", line 84, in <module>
#     main()
#     ~~~~^^
#   File "/Users/utsubo-katsuhiko/src/kanjikana-private/train/conv_scripted.py", line 79, in main
#     KanjiKanaTransformerScripted(args).convert()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/Users/utsubo-katsuhiko/src/kanjikana-private/train/conv_scripted.py", line 35, in convert
#     scripted = torch.jit.script(transformer)
#   File "/Users/utsubo-katsuhiko/src/kanjikana-private/venv/lib/python3.13/site-packages/torch/jit/_script.py", line 1443, in script
#     ret = _script_impl(
#         obj=obj,
#     ...<3 lines>...
#         example_inputs=example_inputs,
#     )
#   File "/Users/utsubo-katsuhiko/src/kanjikana-private/venv/lib/python3.13/site-packages/torch/jit/_script.py", line 1152, in _script_impl
#     return torch.jit._recursive.create_script_module(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         obj, torch.jit._recursive.infer_methods_to_compile
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/utsubo-katsuhiko/src/kanjikana-private/venv/lib/python3.13/site-packages/torch/jit/_recursive.py", line 557, in create_script_module
#     return create_script_module_impl(nn_module, concrete_type, stubs_fn)
#   File "/Users/utsubo-katsuhiko/src/kanjikana-private/venv/lib/python3.13/site-packages/torch/jit/_recursive.py", line 630, in create_script_module_impl
#     create_methods_and_properties_from_stubs(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         concrete_type, method_stubs, property_stubs
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/utsubo-katsuhiko/src/kanjikana-private/venv/lib/python3.13/site-packages/torch/jit/_recursive.py", line 466, in create_methods_and_properties_from_stubs
#     concrete_type._create_methods_and_properties(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         property_defs, property_rcbs, method_defs, method_rcbs, method_defaults
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/utsubo-katsuhiko/src/kanjikana-private/venv/lib/python3.13/site-packages/torch/jit/_recursive.py", line 1027, in compile_unbound_method
#     create_methods_and_properties_from_stubs(concrete_type, (stub,), ())
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/utsubo-katsuhiko/src/kanjikana-private/venv/lib/python3.13/site-packages/torch/jit/_recursive.py", line 466, in create_methods_and_properties_from_stubs
#     concrete_type._create_methods_and_properties(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         property_defs, property_rcbs, method_defs, method_rcbs, method_defaults
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
# RuntimeError:
# Module 'Seq2SeqTransformer' has no attribute '_enc_hiddens' :
#   File "/Users/utsubo-katsuhiko/src/kanjikana-private/train/transformer_model.py", line 127
#     def _clear_intermediates(self):
#         if self.return_intermediate:
#             self._enc_hiddens.clear()
#             ~~~~~~~~~~~~~~~~~ <--- HERE
#             self._dec_hiddens.clear()
# 'Seq2SeqTransformer._clear_intermediates' is being compiled since it was called from 'Seq2SeqTransformer.forward'
#   File "/Users/utsubo-katsuhiko/src/kanjikana-private/train/transformer_model.py", line 140
#                 memory_key_padding_mask: Tensor):
#         #a = self.src_tok_emb(src)
#         self._clear_intermediates()
#         ~~~~~~~~~~~~~~~~~~~~~~~~~ <--- HERE
#         src_emb = self.positional_encoding(self.src_tok_emb(src))
#         tgt_emb = self.positional_encoding(self.tgt_tok_emb(trg))

# %%
# !date
# Out:
# Fri Sep 19 09:59:12 JST 2025
