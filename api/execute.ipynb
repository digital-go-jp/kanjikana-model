# %%
import os

with open('../version.txt','r',encoding='utf-8') as f:
    for l in f:
        ver=l.rstrip()
        break
os.environ['VER']=ver

# %%
# !echo $VER
# Out:
# 1.8o

# %%
# !cat Dockerfile.template|sed "s/VER/$VER/" > Dockerfile

# %%
# !docker stop $(docker ps -a -q)
# !docker rm $(docker ps -a -q)
# Out:
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Error: you must provide at least one name or id
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Error: you must provide at least one name or id

# %%
# !docker build  -t kanjikanaapi:$VER .
# !docker run  --name kanjikanaapi -p 8080:8080 -it kanjikanaapi:$VER
# Out:
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# STEP 1/8: FROM public.ecr.aws/amazonlinux/amazonlinux:2023
# STEP 2/8: RUN dnf -y install glibc-langpack-ja
# --> Using cache e7c6fde98b7154c3558bd235669f71650c91d9b23af17016687acdcbb7960610
# --> e7c6fde98b71
# STEP 3/8: RUN dnf -y install java-21-amazon-corretto-devel
# --> Using cache 092dd7d3949e2b890309ad72e815df159d3719ded23cc65d3cb8df7db1162ae0
# --> 092dd7d3949e
# STEP 4/8: COPY conf/log4j2.xml /log4j2.xml
# --> Using cache 2b813da48924ec804c51f5a624c48e1d961f151e0f2c09486adbf3f31ae88ac1
# --> 2b813da48924
# STEP 5/8: COPY lib/kanjikana_api-1.8o-jar-with-dependencies.jar /app.jar
# --> Using cache 1b5c69893d6bdddc6439865801e4cc69d124402beac9bb6cd078aebeee48a99e
# --> 1b5c69893d6b
# STEP 6/8: COPY .djl.ai/ /root/.djl.ai/
# --> Using cache f55965ee15f809b02c5d946d4b6848aa6e136799f798c9d7f23e53543deb93de
# --> f55965ee15f8
# STEP 7/8: COPY .cache/ /root/.cache/
# --> Using cache a1ce090d4a7a91e50054584be14fe64edbf9224c1a2c3850c7491cd7c851c500
# --> a1ce090d4a7a
# STEP 8/8: ENTRYPOINT ["java","-Xmx8192M","-Dlog4j.configurationFile=/log4j2.xml","-jar","/app.jar" ]
# --> Using cache 559ee075c82d4e50af4e51d39ec9acb41630cc5d366a9f8d4494ce78dd1e9f71
# COMMIT kanjikanaapi:1.8o
# --> 559ee075c82d
# Successfully tagged localhost/kanjikanaapi:1.8o
# 559ee075c82d4e50af4e51d39ec9acb41630cc5d366a9f8d4494ce78dd1e9f71
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
#
#   .   ____          _            __ _ _
#  /\\ / ___'_ __ _ _(_)_ __  __ _ \ \ \ \
# ( ( )\___ | '_ | '_| | '_ \/ _` | \ \ \ \
#  \\/  ___)| |_)| | | | | || (_| |  ) ) ) )
#   '  |____| .__|_| |_|_| |_\__, | / / / /
#  =========|_|==============|___/=/_/_/_/
#  :: Spring Boot ::                (v3.2.2)
#
# 2025-10-24T04:52:16.447Z  INFO 1 --- [           main] jp.go.digital.kanjikana.api.App          : Starting App using Java 21.0.8 with PID 1 (/app.jar started by root in /)
# 2025-10-24T04:52:16.450Z  INFO 1 --- [           main] jp.go.digital.kanjikana.api.App          : No active profile set, falling back to 1 default profile: "default"
# 2025-10-24T04:52:17.388Z  INFO 1 --- [           main] o.s.b.w.embedded.tomcat.TomcatWebServer  : Tomcat initialized with port 8080 (http)
# 2025-10-24T04:52:17.406Z  INFO 1 --- [           main] o.apache.catalina.core.StandardService   : Starting service [Tomcat]
# 2025-10-24T04:52:17.407Z  INFO 1 --- [           main] o.apache.catalina.core.StandardEngine    : Starting Servlet engine: [Apache Tomcat/10.1.18]
# 2025-10-24T04:52:17.504Z  INFO 1 --- [           main] o.a.c.c.C.[Tomcat].[localhost].[/]       : Initializing Spring embedded WebApplicationContext
# 2025-10-24T04:52:17.505Z  INFO 1 --- [           main] w.s.c.ServletWebServerApplicationContext : Root WebApplicationContext: initialization completed in 1009 ms
# 2025-10-24T04:52:17.892Z  WARN 1 --- [           main] ion$DefaultTemplateResolverConfiguration : Cannot find template location: classpath:/templates/ (please add some templates, check your Thymeleaf configuration, or set spring.thymeleaf.check-template-location=false)
# 2025-10-24T04:52:17.985Z  INFO 1 --- [           main] o.s.b.w.embedded.tomcat.TomcatWebServer  : Tomcat started on port 8080 (http) with context path ''
# 2025-10-24T04:52:17.988Z  INFO 1 --- [           main] jp.go.digital.kanjikana.api.App          : Started App in 1.823 seconds (process running for 2.127)
# 2025-10-24T04:52:27.638Z  INFO 1 --- [nio-8080-exec-1] o.a.c.c.C.[Tomcat].[localhost].[/]       : Initializing Spring DispatcherServlet 'dispatcherServlet'
# 2025-10-24T04:52:27.638Z  INFO 1 --- [nio-8080-exec-1] o.s.web.servlet.DispatcherServlet        : Initializing Servlet 'dispatcherServlet'
# 2025-10-24T04:52:27.639Z  INFO 1 --- [nio-8080-exec-1] o.s.web.servlet.DispatcherServlet        : Completed initialization in 1 ms
# 2025-10-24T04:52:57.601Z  INFO 1 --- [nio-8080-exec-3] ai.djl.util.Ec2Utils                     : DJL will collect telemetry to help us better understand our users’ needs, diagnose issues, and deliver additional features. If you would like to learn more or opt-out please go to: https://docs.djl.ai/docs/telemetry.html for more information.
# 2025-10-24T04:52:57.604Z  WARN 1 --- [nio-8080-exec-3] ai.djl.repository.SimpleRepository       : Simple repository pointing to a non-archive file.
# 2025-10-24T04:52:59.596Z  INFO 1 --- [nio-8080-exec-3] ai.djl.pytorch.jni.LibUtils              : Downloading https://publish.djl.ai/pytorch/2.0.1/cpu/linux-x86_64/native/lib/libc10.so.gz ...
# 2025-10-24T04:52:59.632Z  INFO 1 --- [nio-8080-exec-3] ai.djl.pytorch.jni.LibUtils              : Downloading https://publish.djl.ai/pytorch/2.0.1/cpu/linux-x86_64/native/lib/libtorch_cpu.so.gz ...
# 2025-10-24T04:53:03.421Z  INFO 1 --- [nio-8080-exec-3] ai.djl.pytorch.jni.LibUtils              : Downloading https://publish.djl.ai/pytorch/2.0.1/cpu/linux-x86_64/native/lib/libtorch.so.gz ...
# 2025-10-24T04:53:03.428Z  INFO 1 --- [nio-8080-exec-3] ai.djl.pytorch.jni.LibUtils              : Downloading https://publish.djl.ai/pytorch/2.0.1/cpu/linux-x86_64/native/lib/libgomp-52f2fd74.so.1.gz ...
# 2025-10-24T04:53:03.774Z  INFO 1 --- [nio-8080-exec-3] ai.djl.pytorch.jni.LibUtils              : Downloading jni https://publish.djl.ai/pytorch/2.0.1/jnilib/0.25.0/linux-x86_64/cpu/libdjl_torch.so to cache ...
# 2025-10-24T04:53:03.809Z  INFO 1 --- [nio-8080-exec-3] ai.djl.pytorch.engine.PtEngine           : PyTorch graph executor optimizer is enabled, this may impact your inference latency and throughput. See: https://docs.djl.ai/docs/development/inference_performance_optimization.html#graph-executor-optimization
# 2025-10-24T04:53:03.827Z  INFO 1 --- [nio-8080-exec-3] ai.djl.pytorch.engine.PtEngine           : Number of inter-op threads is 8
# 2025-10-24T04:53:03.827Z  INFO 1 --- [nio-8080-exec-3] ai.djl.pytorch.engine.PtEngine           : Number of intra-op threads is 8
# 2025-10-24T04:53:05.008Z  WARN 1 --- [nio-8080-exec-3] ai.djl.repository.SimpleRepository       : Simple repository pointing to a non-archive file.
# 2025-10-24T04:53:05.305Z  WARN 1 --- [nio-8080-exec-3] ai.djl.repository.SimpleRepository       : Simple repository pointing to a non-archive file.
# 2025-10-24T04:53:05.352Z  WARN 1 --- [nio-8080-exec-3] ai.djl.repository.SimpleRepository       : Simple repository pointing to a non-archive file.
# 2025-10-24T04:53:05.799Z  WARN 1 --- [nio-8080-exec-3] ai.djl.repository.SimpleRepository       : Simple repository pointing to a non-archive file.
# 2025-10-24T04:53:05.868Z  WARN 1 --- [nio-8080-exec-3] ai.djl.repository.SimpleRepository       : Simple repository pointing to a non-archive file.
# 2025-10-24T04:53:05.876Z  INFO 1 --- [nio-8080-exec-2] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:05.876Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:06.296Z  INFO 1 --- [nio-8080-exec-2] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:06.300Z  INFO 1 --- [nio-8080-exec-2] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:06.301Z  INFO 1 --- [nio-8080-exec-2] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:06.373Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:06.376Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:06.376Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:06.586Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:06.681Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:06.698Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:06.698Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:06.699Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.062Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.077Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.078Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.079Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.080Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.080Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.116Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.117Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.117Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.126Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.127Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.128Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.279Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.279Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.511Z  INFO 1 --- [nio-8080-exec-2] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.660Z  INFO 1 --- [nio-8080-exec-2] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:07.898Z  INFO 1 --- [nio-8080-exec-2] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:08.239Z  INFO 1 --- [nio-8080-exec-2] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:08.240Z  INFO 1 --- [nio-8080-exec-2] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:08.240Z  INFO 1 --- [nio-8080-exec-2] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:08.248Z  INFO 1 --- [nio-8080-exec-2] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:08.390Z  INFO 1 --- [nio-8080-exec-2] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:08.392Z  INFO 1 --- [nio-8080-exec-2] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:08.392Z  INFO 1 --- [nio-8080-exec-2] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:08.517Z  INFO 1 --- [nio-8080-exec-2] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:08.980Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:08.981Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:08.981Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:08.982Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:08.982Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:08.982Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:09.116Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:09.116Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:09.117Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:09.117Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:09.117Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:09.121Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:09.121Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:09.122Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:09.122Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:09.122Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:09.129Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:09.317Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:09.493Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:09.747Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:09.748Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:09.748Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.047Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.047Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.047Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.048Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.048Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.048Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.057Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.057Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.057Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.058Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.058Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.058Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.062Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.236Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.237Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.238Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:10.238Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.087Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.087Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.088Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.088Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.088Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.097Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.098Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.098Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.098Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.098Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.099Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.101Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.102Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.102Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.102Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.102Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.132Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.132Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.132Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.133Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.192Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.192Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.199Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.199Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.200Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.200Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.200Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.237Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.238Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.238Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.238Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.238Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.239Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.242Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.242Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.243Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.243Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.243Z  INFO 1 --- [io-8080-exec-10] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.453Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.454Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.454Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.454Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.455Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.455Z  INFO 1 --- [nio-8080-exec-1] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.668Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.668Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.669Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.669Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.669Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.673Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.674Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.674Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.674Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.675Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.686Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.686Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.686Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.686Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.687Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.687Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.877Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.877Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.877Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.878Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.878Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.878Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.886Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.886Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.886Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.887Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.887Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.887Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.890Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.890Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.890Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.890Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:21.891Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.643Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.643Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.644Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.644Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.644Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.653Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.653Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.653Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.653Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.654Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.654Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.656Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.656Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.657Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.657Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.657Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.683Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.684Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.684Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.684Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.757Z  INFO 1 --- [nio-8080-exec-6] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.757Z  INFO 1 --- [nio-8080-exec-6] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.764Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.764Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.764Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.764Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.765Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.814Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.814Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.814Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.814Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.815Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.815Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.818Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.818Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.819Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.819Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.819Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.950Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.950Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.951Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.951Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.951Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:35.951Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:36.051Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:36.052Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:53:36.052Z  INFO 1 --- [nio-8080-exec-5] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# ...
# 2025-10-24T04:57:39.065Z  INFO 1 --- [nio-8080-exec-2] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:39.973Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:39.973Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:39.974Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:39.974Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:39.974Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:39.985Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:39.985Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:39.986Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:39.986Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:39.986Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:39.986Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:39.990Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:39.990Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:39.991Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:39.991Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:39.991Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.015Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.015Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.015Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.015Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.097Z  INFO 1 --- [nio-8080-exec-6] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.098Z  INFO 1 --- [nio-8080-exec-6] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.103Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.103Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.103Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.103Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.104Z  INFO 1 --- [nio-8080-exec-7] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.150Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.150Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.150Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.151Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.151Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.151Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.154Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.154Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.154Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.154Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.154Z  INFO 1 --- [nio-8080-exec-8] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.295Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.295Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.295Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.295Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.295Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.295Z  INFO 1 --- [nio-8080-exec-9] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.388Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.388Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.389Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.389Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.389Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.391Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.391Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.391Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.392Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.392Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.397Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.397Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.397Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.398Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.398Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.398Z  INFO 1 --- [nio-8080-exec-4] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.560Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.560Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.560Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.560Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.561Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.561Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.568Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.568Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.568Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.568Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.568Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.569Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.571Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.571Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.571Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.571Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false
# 2025-10-24T04:57:40.571Z  INFO 1 --- [nio-8080-exec-3] j.g.d.k.core.engine.ai.BeamSearch        : BeamSearch (propaties) initialized. parallelEnabled=true, parallelism(auto)=16, legacySelectEachLoop=false

# %%
# !date
