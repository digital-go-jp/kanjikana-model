# %%
import os

with open('../version.txt','r',encoding='utf-8') as f:
    for l in f:
        ver=l.rstrip()
        break
os.environ['VER']=ver

# %%
# !echo $VER
# Out:
# 1.8o

# %%
# !cat Dockerfile.template|sed "s/WEB/$VER/" > Dockerfile

# !mkdir -p .djl.ai
# !mkdir -p .cache

# %%
# !docker stop $(docker ps -a -q)
# !docker rm $(docker ps -a -q)
# Out:
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# baef5e41c088
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# baef5e41c088

# %%
# !docker build  -t kanjikanaapi:$VER .
# !docker run  --name kanjikanaapi -p 8080:8080 -it kanjikanaapi:$VER
# Out:
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
# STEP 1/9: FROM amazonlinux:2023
# STEP 2/9: RUN dnf -y install glibc-langpack-ja
# --> Using cache e7c6fde98b7154c3558bd235669f71650c91d9b23af17016687acdcbb7960610
# --> e7c6fde98b71
# STEP 3/9: RUN dnf -y install java-17-amazon-corretto-devel
# --> Using cache 70def67d4f9ea6294d3162a54b8cefbeb4ab72c5ea39f1b33cfcc6aba134f8eb
# --> 70def67d4f9e
# STEP 4/9: COPY conf/log4j2.xml /log4j2.xml
# --> Using cache cdfc35344417be2903e55af9960c57f05ef415c416f6c481f3129cc710604298
# --> cdfc35344417
# STEP 5/9: COPY lib/kanjikana_api-1.8o-jar-with-dependencies.jar /app.jar
# --> Using cache 6f8de1de24848e6f3bbe271c0b70b241a76693dbed5362dae97c253ec2dd41c5
# --> 6f8de1de2484
# STEP 6/9: COPY lib/kanjikana_core-1.8o-jar-with-dependencies.jar /core.jar
# --> 66946b7e3118
# STEP 7/9: COPY .djl.ai/ /root/.djl.ai/
# --> a1998e8d87f5
# STEP 8/9: COPY .cache/ /root/.cache/
# --> 39421355f636
# STEP 9/9: ENTRYPOINT ["java","-Xmx8192M","-Dlog4j.configurationFile=/log4j2.xml","-cp","/core.jar","-jar","/app.jar" ]
# COMMIT kanjikanaapi:1.8o
# --> a692d9770774
# Successfully tagged localhost/kanjikanaapi:1.8o
# a692d9770774912f10e4b09acf0c33ffb654029c4b3a497bd70ab66d5db2c298
# Emulate Docker CLI using podman. Create /etc/containers/nodocker to quiet msg.
#
#   .   ____          _            __ _ _
#  /\\ / ___'_ __ _ _(_)_ __  __ _ \ \ \ \
# ( ( )\___ | '_ | '_| | '_ \/ _` | \ \ \ \
#  \\/  ___)| |_)| | | | | || (_| |  ) ) ) )
#   '  |____| .__|_| |_|_| |_\__, | / / / /
#  =========|_|==============|___/=/_/_/_/
#  :: Spring Boot ::                (v3.2.2)
#
# 2025-10-08T07:26:49.487Z  INFO 1 --- [           main] jp.go.digital.kanjikana.api.App          : Starting App using Java 17.0.16 with PID 1 (/app.jar started by root in /)
# 2025-10-08T07:26:49.490Z  INFO 1 --- [           main] jp.go.digital.kanjikana.api.App          : No active profile set, falling back to 1 default profile: "default"
# 2025-10-08T07:26:50.314Z  INFO 1 --- [           main] o.s.b.w.embedded.tomcat.TomcatWebServer  : Tomcat initialized with port 8080 (http)
# 2025-10-08T07:26:50.324Z  INFO 1 --- [           main] o.apache.catalina.core.StandardService   : Starting service [Tomcat]
# 2025-10-08T07:26:50.324Z  INFO 1 --- [           main] o.apache.catalina.core.StandardEngine    : Starting Servlet engine: [Apache Tomcat/10.1.18]
# 2025-10-08T07:26:50.426Z  INFO 1 --- [           main] o.a.c.c.C.[Tomcat].[localhost].[/]       : Initializing Spring embedded WebApplicationContext
# 2025-10-08T07:26:50.428Z  INFO 1 --- [           main] w.s.c.ServletWebServerApplicationContext : Root WebApplicationContext: initialization completed in 895 ms
# 2025-10-08T07:26:50.608Z  WARN 1 --- [           main] ConfigServletWebServerApplicationContext : Exception encountered during context initialization - cancelling refresh attempt: org.springframework.beans.factory.BeanCreationException: Error creating bean with name 'aiController': Lookup method resolution failed
# 2025-10-08T07:26:50.610Z  INFO 1 --- [           main] o.apache.catalina.core.StandardService   : Stopping service [Tomcat]
# 2025-10-08T07:26:50.626Z ERROR 1 --- [           main] o.s.boot.SpringApplication               : Application run failed
#
# org.springframework.beans.factory.BeanCreationException: Error creating bean with name 'aiController': Lookup method resolution failed
# 	at org.springframework.beans.factory.annotation.AutowiredAnnotationBeanPostProcessor.checkLookupMethods(AutowiredAnnotationBeanPostProcessor.java:497) ~[app.jar:na]
# 	at org.springframework.beans.factory.annotation.AutowiredAnnotationBeanPostProcessor.determineCandidateConstructors(AutowiredAnnotationBeanPostProcessor.java:367) ~[app.jar:na]
# 	at org.springframework.beans.factory.support.AbstractAutowireCapableBeanFactory.determineConstructorsFromBeanPostProcessors(AbstractAutowireCapableBeanFactory.java:1293) ~[app.jar:na]
# 	at org.springframework.beans.factory.support.AbstractAutowireCapableBeanFactory.createBeanInstance(AbstractAutowireCapableBeanFactory.java:1188) ~[app.jar:na]
# 	at org.springframework.beans.factory.support.AbstractAutowireCapableBeanFactory.doCreateBean(AbstractAutowireCapableBeanFactory.java:561) ~[app.jar:na]
# 	at org.springframework.beans.factory.support.AbstractAutowireCapableBeanFactory.createBean(AbstractAutowireCapableBeanFactory.java:521) ~[app.jar:na]
# 	at org.springframework.beans.factory.support.AbstractBeanFactory.lambda$doGetBean$0(AbstractBeanFactory.java:325) ~[app.jar:na]
# 	at org.springframework.beans.factory.support.DefaultSingletonBeanRegistry.getSingleton(DefaultSingletonBeanRegistry.java:234) ~[app.jar:na]
# 	at org.springframework.beans.factory.support.AbstractBeanFactory.doGetBean(AbstractBeanFactory.java:323) ~[app.jar:na]
# 	at org.springframework.beans.factory.support.AbstractBeanFactory.getBean(AbstractBeanFactory.java:199) ~[app.jar:na]
# 	at org.springframework.beans.factory.support.DefaultListableBeanFactory.preInstantiateSingletons(DefaultListableBeanFactory.java:975) ~[app.jar:na]
# 	at org.springframework.context.support.AbstractApplicationContext.finishBeanFactoryInitialization(AbstractApplicationContext.java:959) ~[app.jar:na]
# 	at org.springframework.context.support.AbstractApplicationContext.refresh(AbstractApplicationContext.java:624) ~[app.jar:na]
# 	at org.springframework.boot.web.servlet.context.ServletWebServerApplicationContext.refresh(ServletWebServerApplicationContext.java:146) ~[app.jar:na]
# 	at org.springframework.boot.SpringApplication.refresh(SpringApplication.java:754) ~[app.jar:na]
# 	at org.springframework.boot.SpringApplication.refreshContext(SpringApplication.java:456) ~[app.jar:na]
# 	at org.springframework.boot.SpringApplication.run(SpringApplication.java:334) ~[app.jar:na]
# 	at org.springframework.boot.SpringApplication.run(SpringApplication.java:1354) ~[app.jar:na]
# 	at org.springframework.boot.SpringApplication.run(SpringApplication.java:1343) ~[app.jar:na]
# 	at jp.go.digital.kanjikana.api.App.main(App.java:43) ~[app.jar:na]
# Caused by: java.lang.IllegalStateException: Failed to introspect Class [jp.go.digital.kanjikana.api.match.AiController] from ClassLoader [jdk.internal.loader.ClassLoaders$AppClassLoader@30946e09]
# 	at org.springframework.util.ReflectionUtils.getDeclaredMethods(ReflectionUtils.java:483) ~[app.jar:na]
# 	at org.springframework.util.ReflectionUtils.doWithLocalMethods(ReflectionUtils.java:320) ~[app.jar:na]
# 	at org.springframework.beans.factory.annotation.AutowiredAnnotationBeanPostProcessor.checkLookupMethods(AutowiredAnnotationBeanPostProcessor.java:475) ~[app.jar:na]
# 	... 19 common frames omitted
# Caused by: java.lang.NoClassDefFoundError: jp/go/digital/kanjikana/core/executor/Output
# 	at java.base/java.lang.Class.getDeclaredMethods0(Native Method) ~[na:na]
# 	at java.base/java.lang.Class.privateGetDeclaredMethods(Class.java:3402) ~[na:na]
# 	at java.base/java.lang.Class.getDeclaredMethods(Class.java:2504) ~[na:na]
# 	at org.springframework.util.ReflectionUtils.getDeclaredMethods(ReflectionUtils.java:465) ~[app.jar:na]
# 	... 21 common frames omitted
# Caused by: java.lang.ClassNotFoundException: jp.go.digital.kanjikana.core.executor.Output
# 	at java.base/jdk.internal.loader.BuiltinClassLoader.loadClass(BuiltinClassLoader.java:641) ~[na:na]
# 	at java.base/jdk.internal.loader.ClassLoaders$AppClassLoader.loadClass(ClassLoaders.java:188) ~[na:na]
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:525) ~[na:na]
# 	... 25 common frames omitted
