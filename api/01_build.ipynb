# %% [markdown]
# ECR対応する

# %%
import os

with open('../core/version.txt','r',encoding='utf-8') as f:
    for l in f:
        ver=l.rstrip()
        break
os.environ['VER']=ver

# %%
print(ver)
# Out:
# 1.7

# %%
# !mkdir -p lib

# %%
# !rm -rf lib/kanjikana_core-${VER}-jar-with-dependencies.jar
# !cp -rp ../core/lib/kanjikana_core-${VER}-jar-with-dependencies.jar lib/

# %%
# !rm -rf target

# %%
# !cat pom.xml.template|sed "s/VER/$VER/"|sed "s/WEB/$VER/" > pom.xml

# %%
# !mvn clean compile assembly:single
# !mvn javadoc:javadoc
# Out:
# zsh:1: command not found: mvn
# zsh:1: command not found: mvn

# %%
# !nfname=`ls target/kanjikana_api-${VER}-jar-with-dependencies.jar`
# !zip -d $nfname jp/go/digital/kanjikana/core/executor/generate/Kana2KanjiMain.class
# !zip -d $nfname jp/go/digital/kanjikana/core/executor/generate/Kanji2KanaMain.class
# !zip -d $nfname jp/go/digital/kanjikana/core/executor/match/KanjiKanaMatchMain.class
# Out:
# ls: 'target/kanjikana_api--jar-with-dependencies.jar' にアクセスできません: そのようなファイルやディレクトリはありません
# 	zip warning: jp/go/digital/kanjikana/core/executor/generate/Kana2KanjiMain.class not found or empty
#
# zip error: Nothing to do! (jp/go/digital/kanjikana/core/executor/generate/Kana2KanjiMain.class)
# 	zip warning: jp/go/digital/kanjikana/core/executor/generate/Kanji2KanaMain.class not found or empty
#
# zip error: Nothing to do! (jp/go/digital/kanjikana/core/executor/generate/Kanji2KanaMain.class)
# 	zip warning: jp/go/digital/kanjikana/core/executor/match/KanjiKanaMatchMain.class not found or empty
#
# zip error: Nothing to do! (jp/go/digital/kanjikana/core/executor/match/KanjiKanaMatchMain.class)

# %%
# !cp -pr target/kanjikana_api-${VER}-jar-with-dependencies.jar lib/.
# Out:
# cp: 'target/kanjikana_api--jar-with-dependencies.jar' を stat できません: そのようなファイルやディレクトリはありません
