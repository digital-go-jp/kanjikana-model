# %% [markdown]
# ECR対応する

# %%
import os

with open('../version.txt','r',encoding='utf-8') as f:
    for l in f:
        ver=l.rstrip()
        break
os.environ['VER']=ver

# %%
print(ver)
# Out:
# 1.8o

# %%
# !mkdir -p lib

# %%
# !mvn install:install-file -Dfile=../core/lib/kanjikana_core-1.8o-jar-with-dependencies.jar -DgroupId=jp.go.digital.kanjikana -DartifactId=kanjikana_core -Dversion=1.8o -Dpackaging=jar
# Out:
# WARNING: A terminally deprecated method in sun.misc.Unsafe has been called
# WARNING: sun.misc.Unsafe::staticFieldBase has been called by com.google.inject.internal.aop.HiddenClassDefiner (file:/opt/homebrew/Cellar/maven/3.9.11/libexec/lib/guice-5.1.0-classes.jar)
# WARNING: Please consider reporting this to the maintainers of class com.google.inject.internal.aop.HiddenClassDefiner
# WARNING: sun.misc.Unsafe::staticFieldBase will be removed in a future release
# [INFO] Scanning for projects...
# [INFO]
# [INFO] -------------< jp.go.digital.kanjikana.api:kanjikana_api >--------------
# [INFO] Building kanjikana_api 1.8o
# [INFO]   from pom.xml
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- install:3.1.1:install-file (default-cli) @ kanjikana_api ---
# [INFO] Installing /Users/utsubo-katsuhiko/src/kanjikana-model/core/lib/kanjikana_core-1.8o-jar-with-dependencies.jar to /Users/utsubo-katsuhiko/.m2/repository/jp/go/digital/kanjikana/kanjikana_core/1.8o/kanjikana_core-1.8o.jar
# [INFO] Installing /var/folders/wq/wprczkf944x4pbbn3fmpqjkc0000gp/T/kanjikana_core-1.8o-jar-with-dependencies18399414113334657577.pom to /Users/utsubo-katsuhiko/.m2/repository/jp/go/digital/kanjikana/kanjikana_core/1.8o/kanjikana_core-1.8o.pom
# [WARNING] Artifact jp.go.digital.kanjikana:kanjikana_core JAR (about to be installed/deployed) contains Maven Plugin metadata for conflicting coordinates: org.apache.maven.plugins:maven-dependency-plugin. Your JAR contains rogue Maven Plugin metadata. Possible causes may be: shaded into this JAR some Maven Plugin or some rogue resource.
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  0.209 s
# [INFO] Finished at: 2025-10-14T14:05:13+09:00
# [INFO] ------------------------------------------------------------------------

# %%
# !rm -rf target

# %%
# !cat pom.xml.template|sed "s/VER/$VER/"|sed "s/WEB/$VER/" > pom.xml

# %%
# !mvn clean package -Dmaven.test.skip=true
# Out:
# WARNING: A terminally deprecated method in sun.misc.Unsafe has been called
# WARNING: sun.misc.Unsafe::staticFieldBase has been called by com.google.inject.internal.aop.HiddenClassDefiner (file:/opt/homebrew/Cellar/maven/3.9.11/libexec/lib/guice-5.1.0-classes.jar)
# WARNING: Please consider reporting this to the maintainers of class com.google.inject.internal.aop.HiddenClassDefiner
# WARNING: sun.misc.Unsafe::staticFieldBase will be removed in a future release
# [INFO] Scanning for projects...
# [INFO]
# [INFO] -------------< jp.go.digital.kanjikana.api:kanjikana_api >--------------
# [INFO] Building kanjikana_api 1.8o
# [INFO]   from pom.xml
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- clean:3.3.2:clean (default-clean) @ kanjikana_api ---
# [INFO] Deleting /Users/utsubo-katsuhiko/src/kanjikana-model/api/target
# [INFO]
# [INFO] --- install:3.1.1:install-file (install-external) @ kanjikana_api ---
# [INFO] Installing /Users/utsubo-katsuhiko/src/kanjikana-model/api/../core/lib/kanjikana_core-1.8o-jar-with-dependencies.jar to /Users/utsubo-katsuhiko/.m2/repository/jp/go/digital/kanjikana/kanjikana_core/1.8o/kanjikana_core-1.8o.jar
# [INFO] Installing /var/folders/wq/wprczkf944x4pbbn3fmpqjkc0000gp/T/mvninstall5340615952700041760.pom to /Users/utsubo-katsuhiko/.m2/repository/jp/go/digital/kanjikana/kanjikana_core/1.8o/kanjikana_core-1.8o.pom
# [WARNING] Artifact jp.go.digital.kanjikana:kanjikana_core JAR (about to be installed/deployed) contains Maven Plugin metadata for conflicting coordinates: org.apache.maven.plugins:maven-dependency-plugin. Your JAR contains rogue Maven Plugin metadata. Possible causes may be: shaded into this JAR some Maven Plugin or some rogue resource.
# [INFO]
# [INFO] --- resources:3.3.1:resources (default-resources) @ kanjikana_api ---
# [INFO] skip non existing resourceDirectory /Users/utsubo-katsuhiko/src/kanjikana-model/api/src/main/resources
# [INFO] skip non existing resourceDirectory /Users/utsubo-katsuhiko/src/kanjikana-model/api/src/main/resources
# [INFO]
# [INFO] --- compiler:3.11.0:compile (default-compile) @ kanjikana_api ---
# [INFO] Changes detected - recompiling the module! :source
# [INFO] Compiling 14 source files with javac [debug release 17] to target/classes
# [INFO]
# [INFO] --- resources:3.3.1:testResources (default-testResources) @ kanjikana_api ---
# [INFO] Not copying test resources
# [INFO]
# [INFO] --- compiler:3.11.0:testCompile (default-testCompile) @ kanjikana_api ---
# [INFO] Not compiling test sources
# [INFO]
# [INFO] --- surefire:3.1.2:test (default-test) @ kanjikana_api ---
# [INFO] Tests are skipped.
# [INFO]
# [INFO] --- jar:3.3.0:jar (default-jar) @ kanjikana_api ---
# [INFO] Building jar: /Users/utsubo-katsuhiko/src/kanjikana-model/api/target/kanjikana_api-1.8o.jar
# [INFO]
# [INFO] --- assembly:3.6.0:single (default) @ kanjikana_api ---
# [INFO] Building jar: /Users/utsubo-katsuhiko/src/kanjikana-model/api/target/kanjikana_api-1.8o-jar-with-dependencies.jar
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  59.215 s
# [INFO] Finished at: 2025-10-14T14:06:14+09:00
# [INFO] ------------------------------------------------------------------------

# %%
# !mv  target/kanjikana_api-${VER}-jar-with-dependencies.jar lib/.

# %%
# !date
# Out:
# Tue Oct 14 14:06:14 JST 2025
