# %% [markdown]
# JAVAから使うように，JSONファイルへマージ，変換する

# %%
import os
os.environ['VER']='1.7o'
os.environ['DIR']=f"data/data.{os.environ['VER']}"

# %%
# !mkdir -p $DIR

# %%
import json

# %%
# !mv tankanji2.json $DIR/tankanji_$VER.json

# %%
# !echo "{}" > $DIR/statistics_$VER.json

# %%
# !mv itaiji.json $DIR/itaiji_$VER.json
# Out:
# mv: 'itaiji.json' を stat できません: そのようなファイルやディレクトリはありません

# %% [markdown]
# reliable.json

# %%
# !mv oss2.json $DIR/reliable_$VER.json

# %% [markdown]
# unreliable.json

# %%
# !mv seimei2.json $DIR/unreliable_$VER.json

# %%
# !date
# Out:
# 2025年  6月 19日 木曜日 13:16:57 JST
